# %% [markdown]
# ## 4.1_Convert Text to Speech Using gTTS

# %%
# !pip install gTTS
# Out:
# Collecting gTTS
#   Downloading gTTS-2.2.3-py3-none-any.whl (25 kB)
# Requirement already satisfied: click in c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages (from gTTS) (6.7)
# Requirement already satisfied: requests in c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages (from gTTS) (2.27.1)
# Requirement already satisfied: six in c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages (from gTTS) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages (from requests->gTTS) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages (from requests->gTTS) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages (from requests->gTTS) (2.0.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages (from requests->gTTS) (3.3)
# Installing collected packages: gTTS
# Successfully installed gTTS-2.2.3
# WARNING: Ignoring invalid distribution -rpcio (c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -rpcio (c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rpcio (c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rpcio (c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -rpcio (c:\users\akash_shrivastava\appdata\roaming\python\python36\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash_shrivastava\appdata\local\continuum\anaconda3\lib\site-packages)

# %%
# Import the required module for text  
# to speech conversion 
from gtts import gTTS

# %%
# The text that you want to convert to audio 
mytext = 'Audiobook industry is booming nowadays'
  
# Language in which you want to convert 
language = 'fr'

# %%
# Passing the text and language to the engine,  
# here we have marked slow=False. Which tells  
# the module that the converted audio should  
# have a high speed 
myobj = gTTS(text=mytext, lang=language, slow=False) 
  
# Saving the converted audio in a mp3 file named 
# welcome  
myobj.save("test.mp3")

# %%
#Visualizing audio

import librosa
audio_file_path='test_1.wav'
x, sr = librosa.load(audio_file_path)

# %%
print(x.shape)
print(sr)
# Out:
# (84143,)
# 22050

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
import IPython.display as ipd
ipd.Audio('test_1.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
